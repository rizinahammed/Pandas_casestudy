# %% [markdown]
# <a href="https://colab.research.google.com/github/rizinahammed/Pandas_casestudy/blob/main/Pandas_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Import pandas, numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2) Load dataset using pd.read_csv()

# %%
df=pd.read_csv("https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 3) Display: shape, head, column names, datatypes, missing value

# %%
#shape
df.shape
# Out:
# (1000, 12)

# %%
#Head
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#columns
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#datatypes
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
#missing values
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
#missing values
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# 4) Check and remove duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 5) Rename columns ("Title" > "Movie_Title")

# %%
df=df.rename(columns={"Title":"Movie_Title"})
df.head(3)
# Out:
#    Rank              Movie_Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %% [markdown]
# 6) Get unique genres

# %%
df['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %% [markdown]
# 7) Extract number of genres per movie

# %%
df["no.of genres"]=df['Genre'].apply(lambda x: len(x.split(",")))
df[["Movie_Title","no.of genres"]]
# Out:
#                  Movie_Title  no.of genres
# 0    Guardians of the Galaxy             3
# 1                 Prometheus             3
# 2                      Split             2
# 3                       Sing             3
# 4              Suicide Squad             3
# ..                       ...           ...
# 995     Secret in Their Eyes             3
# 996          Hostel: Part II             1
# 997   Step Up 2: The Streets             3
# 998             Search Party             2
# 999               Nine Lives             3
#
# [1000 rows x 2 columns]

# %% [markdown]
# 8) Handle missing values in 'Revenue (Millions)' and 'Metascore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie_Title         1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
#  12  no.of genres        1000 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
df[['Revenue (Millions)', 'Metascore']].isnull()
# Out:
#      Revenue (Millions)  Metascore
# 0                 False      False
# 1                 False      False
# 2                 False      False
# 3                 False      False
# 4                 False      False
# ..                  ...        ...
# 995                True      False
# 996               False      False
# 997               False      False
# 998                True      False
# 999               False      False
#
# [1000 rows x 2 columns]

# %%
df[['Revenue (Millions)', 'Metascore']].isnull().sum()
# Out:
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# Handle missing values in Revenue (Millions)

# %%
a=df["Revenue (Millions)"].mean()
a
# Out:
# np.float64(82.95637614678898)

# %%
df['Revenue (Millions)'] = df['Revenue (Millions)'].fillna(a)
df['Revenue (Millions)']
# Out:
# 0      333.130000
# 1      126.460000
# 2      138.120000
# 3      270.320000
# 4      325.020000
#           ...
# 995     82.956376
# 996     17.540000
# 997     58.010000
# 998     82.956376
# 999     19.640000
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
df['Revenue (Millions)'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handle missing values in Metascore

# %%
df['Metascore'].isnull().sum()
# Out:
# np.int64(64)

# %%
b=df["Metascore"].mean()
b
# Out:
# np.float64(58.98504273504273)

# %%
df["Metascore"]=df["Metascore"].fillna(b)
df["Metascore"]
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
#        ...
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
df["Metascore"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 9) Top 5 movies by Rating

# %%
top= df.sort_values(by='Rating', ascending=False)
top5=top.head(5)
top5
# Out:
#      Rank       Movie_Title                    Genre  \
# 54     55   The Dark Knight       Action,Crime,Drama
# 80     81         Inception  Action,Adventure,Sci-Fi
# 117   118            Dangal   Action,Biography,Drama
# 36     37      Interstellar   Adventure,Drama,Sci-Fi
# 249   250  The Intouchables   Biography,Comedy,Drama
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %% [markdown]
# 10) Movies with highest/lowest revenue

# %%
#highest revenue movie
df.loc[df['Revenue (Millions)'].idxmax()][['Movie_Title','Revenue (Millions)']]
# Out:
# Movie_Title           Star Wars: Episode VII - The Force Awakens
# Revenue (Millions)                                        936.63
# Name: 50, dtype: object

# %%
#lowest revenue movie
df.loc[df['Revenue (Millions)'].idxmin()][["Movie_Title",'Revenue (Millions)']]
# Out:
# Movie_Title           A Kind of Murder
# Revenue (Millions)                 0.0
# Name: 231, dtype: object

# %% [markdown]
# 11) Avg. rating by Director

# %%
df.groupby("Director")["Rating"].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# 12) Movies per year

# %%
df["Year"].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %% [markdown]
# 13) Movies with rating > 8 & revenue > 100M

# %%
df[(df["Rating"]>8)& (df["Revenue (Millions)"]>100)][["Movie_Title","Rating","Revenue (Millions)"]]
# Out:
#                                       Movie_Title  Rating  Revenue (Millions)
# 0                         Guardians of the Galaxy     8.1              333.13
# 6                                      La La Land     8.3              151.06
# 36                                   Interstellar     8.6              187.99
# 50     Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 54                                The Dark Knight     9.0              533.32
# 67                             Mad Max: Fury Road     8.1              153.63
# 74                                       Zootopia     8.1              341.26
# 76                                   The Avengers     8.1              623.28
# 77                           Inglourious Basterds     8.3              120.52
# 80                                      Inception     8.8              292.57
# 82                        The Wolf of Wall Street     8.2              116.87
# ...

# %% [markdown]
# 14) Group by Director: avg Rating, Revenue

# %%
df.groupby("Director")[["Rating","Revenue (Millions)"]].mean()
# Out:
#                      Rating  Revenue (Millions)
# Director
# Aamir Khan             8.50            1.200000
# Abdellatif Kechiche    7.80            2.200000
# Adam Leon              6.50           82.956376
# Adam McKay             7.00          109.535000
# Adam Shankman          6.30           78.665000
# ...                     ...                 ...
# Xavier Dolan           7.55           43.223188
# Yimou Zhang            6.10           45.130000
# Yorgos Lanthimos       7.20            4.405000
# Zack Snyder            7.04          195.148000
# Zackary Adler          5.10            6.530000
#
# [644 rows x 2 columns]

# %% [markdown]
# 15) Group by Year: count, avg Rating

# %%
df.groupby("Year")[["Rating"]].agg(["count","mean"])
# Out:
#      Rating
#       count      mean
# Year
# 2006     44  7.125000
# 2007     53  7.133962
# 2008     52  6.784615
# 2009     51  6.960784
# 2010     60  6.826667
# 2011     63  6.838095
# 2012     64  6.925000
# 2013     91  6.812088
# 2014     98  6.837755
# 2015    127  6.602362
# 2016    297  6.436700

# %% [markdown]
# 16) Create a new column Profitability:
# a) Revenue divided by Duration
# b) Find top 10 most profitable movies

# %%
# a) Revenue divided by Duration
df["Profitability"]=df["Revenue (Millions)"] / df["Runtime (Minutes)"]
df.head(3)
# Out:
#    Rank              Movie_Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore  no.of genres  Profitability
# ...

# %%
#b) Find top 10 most profitable movies
df.nlargest(10,"Profitability")[["Movie_Title","Profitability"]]
# Out:
#                                     Movie_Title  Profitability
# 50   Star Wars: Episode VII - The Force Awakens       6.886985
# 85                               Jurassic World       5.259516
# 119                                Finding Dory       5.013299
# 87                                       Avatar       4.694506
# 76                                 The Avengers       4.358601
# 15                      The Secret Life of Pets       4.233448
# 688                                 Toy Story 3       4.028932
# 12                                    Rogue One       4.001278
# 174                                      Frozen       3.928824
# 797                             Despicable Me 2       3.755612

# %% [markdown]
# 17) Create a column that categorizes movies by rating:
# a) Rating < 6: Poor
# b) 6 ≤ Rating < 7.5: Average
# c) Rating ≥ 7.5: Excellent

# %%
#a) Rating < 6: Poor
df["category"]=df["Rating"].apply(lambda x:"poor" if x<6 else None)
#b) 6 ≤ Rating < 7.5: Average
df.loc[(df["Rating"]>=6)&(df["Rating"]<=7.5),"category"]="average"
#c) Rating ≥ 7.5: Excellent
df.loc[df["Rating"]>=7.5,"category"]="exellent"
df[["Movie_Title","Rating","category"]].head(5)
# Out:
#                Movie_Title  Rating  category
# 0  Guardians of the Galaxy     8.1  exellent
# 1               Prometheus     7.0   average
# 2                    Split     7.3   average
# 3                     Sing     7.2   average
# 4            Suicide Squad     6.2   average

# %% [markdown]
# 18) Create a custom function to score movies based on:
# i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score
# Apply a function to dataset to assign the score

# %%
def score_movie(row):
    return row['Rating'] * 10 + row['Revenue (Millions)']

df['Score'] = df.apply(score_movie, axis=1)
df[['Movie_Title', 'Score']].head(3)
# Out:
#                Movie_Title   Score
# 0  Guardians of the Galaxy  414.13
# 1               Prometheus  196.46
# 2                    Split  211.12
